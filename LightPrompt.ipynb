# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmahmoodiagents/Basics/blob/main/LightPrompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import langchain

# %%
langchain.__version__
# Out:
# '1.2.0'

# %%
# !pip install langchain_openai --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.1/489.1 kB 24.5 MB/s eta 0:00:00

# %%
from langchain_openai import ChatOpenAI

# %%
import os, getpass

# %%
os.environ['OPENAI_API_KEY'] = getpass.getpass()
# Out:
# ··········

# %%
llm = ChatOpenAI(model='gpt-4o-mini')

# %%
res = llm.invoke("what is the capital on India? Please answer in short")

# %%
res.content
# Out:
# 'The capital of India is New Delhi.'
